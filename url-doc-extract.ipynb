# %% [markdown]
# ### import libraries

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse, urljoin, urlunparse
import os
import re
import pickle

# %% [markdown]
# #### 1. Scrape the documentation from the URL

# %%
# Url to scrape
docs_url = "https://fastapi.tiangolo.com/tutorial/"

# %%
def is_valid_url(url, base_url):
    """
    Helper method to check if the URL is valid and belongs to the same domain as the base URL.
    """
    parsed = urlparse(url)
    base_parsed = urlparse(base_url)
    return bool(parsed.netloc) and parsed.netloc == base_parsed.netloc

# %%
def extract_links(soup, base_url):
    """
    Helper method to extract all valid links from the BeautifulSoup object.
    """
    links = set()
    for a_tag in soup.find_all('a', href=True):
        href = a_tag['href']
        full_url = urljoin(base_url, href)
        if is_valid_url(full_url, base_url):
            links.add(full_url)
    return links

# %%
def get_html_content(soup):
    """Extract relevant main HTML content and convert it to Markdown-like text."""
    # Locate main content container
    main_content = (
        soup.find("main")
        or soup.find("article")
        or soup.find("div", class_="content")
        or soup.find("div", class_="main-content")
        or soup.body
    )
    
    # Remove navigation/sidebars/menus
    for tag in main_content.find_all(["nav", "aside", "header", "footer"]):
        tag.decompose()
    for tag in main_content.find_all(attrs={"class": lambda c: c and ("sidebar" in c or "menu" in c)}):
        tag.decompose()
    for tag in main_content.find_all(attrs={"id": lambda i: i and ("sidebar" in i or "menu" in i)}):
        tag.decompose()
    
    # Convert remaining elements to Markdown
    parts = []
    for tag in main_content.find_all(["h1", "h2", "h3", "p", "pre", "code", "li"]):
        if tag.name == "h1":
            parts.append(f"# {tag.get_text(strip=True)}")
        elif tag.name == "h2":
            parts.append(f"## {tag.get_text(strip=True)}")
        elif tag.name == "h3":
            parts.append(f"### {tag.get_text(strip=True)}")
        elif tag.name == "p":
            parts.append(tag.get_text(strip=True))
        elif tag.name in ["pre", "code"]:
            code_lang = tag.get('class', [''])[0] if tag.get('class') else ''
            parts.append(f"```{code_lang}\n{tag.get_text(strip=True)}\n```")
        elif tag.name == "li":
            parts.append(f"- {tag.get_text(strip=True)}")
    
    return "\n\n".join(parts)

# %%
def normalize_url(url):
    """Normalize URL by removing fragment and query, ensuring consistent format."""
    parsed = urlparse(url)
    # Remove query and fragment to avoid duplicates like /page?id=1 or /page#section
    normalized = parsed._replace(query="", fragment="")
    # Ensure scheme and netloc are lowercase, path stays the same
    return urlunparse(normalized).rstrip("/")

def crawl_and_scrape(base_url, max_pages=250):
    """
    Crawl the site starting from the base URL and extract the HTML content of each page.
    """
    visited = set()
    to_visit = {normalize_url(base_url)}
    all_content = dict()

    while to_visit and len(visited) < max_pages:
        current_url = to_visit.pop()
        if current_url in visited:
            continue

        print(f"{len(visited)}/{max_pages} Crawling: {current_url}")
        visited.add(current_url)

        try:
            response = requests.get(current_url)
            response.raise_for_status()
            soup = BeautifulSoup(response.text, 'html.parser')

            # Normalize and filter links before adding
            links = {
                normalize_url(link)
                for link in extract_links(soup, base_url)
            }
            to_visit.update(links - visited)

            html_content = get_html_content(soup)
            all_content[current_url] = html_content

        except requests.RequestException as e:
            print(f"An error occurred while fetching the URL: {e}")

    return all_content

# %%
doc_sites = crawl_and_scrape(docs_url)
# Out:
# 0/250 Crawling: https://fastapi.tiangolo.com/tutorial
# 1/250 Crawling: https://fastapi.tiangolo.com/advanced/security/http-basic-auth
# 2/250 Crawling: https://fastapi.tiangolo.com/advanced/using-request-directly
# 3/250 Crawling: https://fastapi.tiangolo.com/tutorial/query-params-str-validations
# 4/250 Crawling: https://fastapi.tiangolo.com/ur
# 5/250 Crawling: https://fastapi.tiangolo.com/reference/dependencies
# 6/250 Crawling: https://fastapi.tiangolo.com/de
# 7/250 Crawling: https://fastapi.tiangolo.com/tutorial/how-to/testing-database
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/how-to/testing-database
# 8/250 Crawling: https://fastapi.tiangolo.com/deployment/manually
# 9/250 Crawling: https://fastapi.tiangolo.com/tutorial/tutorial/response-model
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/tutorial/response-model
# 10/250 Crawling: https://fastapi.tiangolo.com/tutorial/advanced/testing-events
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/advanced/testing-events
# 11/250 Crawling: https://fastapi.tiangolo.com/templating
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/templating
# 12/250 Crawling: https://fastapi.tiangolo.com/advanced/security/oauth2-scopes
# 13/250 Crawling: https://fastapi.tiangolo.com/help-fastapi
# 14/250 Crawling: https://fastapi.tiangolo.com/body
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/body
# 15/250 Crawling: https://fastapi.tiangolo.com/reference/middleware
# 16/250 Crawling: https://fastapi.tiangolo.com/zh
# 17/250 Crawling: https://fastapi.tiangolo.com/header-param-models
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/header-param-models
# 18/250 Crawling: https://fastapi.tiangolo.com/using-request-directly
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/using-request-directly
# 19/250 Crawling: https://fastapi.tiangolo.com/tutorial/reference/testclient
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/reference/testclient
# 20/250 Crawling: https://fastapi.tiangolo.com/tutorial/project-generation
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/project-generation
# 21/250 Crawling: https://fastapi.tiangolo.com/external-links
# 22/250 Crawling: https://fastapi.tiangolo.com/path-operation-configuration
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/path-operation-configuration
# 23/250 Crawling: https://fastapi.tiangolo.com/tutorial/how-to/conditional-openapi
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/how-to/conditional-openapi
# 24/250 Crawling: https://fastapi.tiangolo.com/oauth2-scopes
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/oauth2-scopes
# 25/250 Crawling: https://fastapi.tiangolo.com/nl
# 26/250 Crawling: https://fastapi.tiangolo.com/tutorial/request-form-models
# 27/250 Crawling: https://fastapi.tiangolo.com/advanced/response-change-status-code
# 28/250 Crawling: https://fastapi.tiangolo.com/tutorial/reference/parameters
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/reference/parameters
# 29/250 Crawling: https://fastapi.tiangolo.com/sub-applications
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/sub-applications
# 30/250 Crawling: https://fastapi.tiangolo.com/tutorial/cors
# 31/250 Crawling: https://fastapi.tiangolo.com/body-multiple-params
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/body-multiple-params
# 32/250 Crawling: https://fastapi.tiangolo.com/request-forms
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/request-forms
# 33/250 Crawling: https://fastapi.tiangolo.com/zh/benchmarks
# 34/250 Crawling: https://fastapi.tiangolo.com/advanced/templates
# 35/250 Crawling: https://fastapi.tiangolo.com/tutorial/reference/uploadfile
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/reference/uploadfile
# 36/250 Crawling: https://fastapi.tiangolo.com/dependencies/dependencies-in-path-operation-decorators
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/dependencies/dependencies-in-path-operation-decorators
# 37/250 Crawling: https://fastapi.tiangolo.com/environment-variables
# 38/250 Crawling: https://fastapi.tiangolo.com/tutorial/header-params
# 39/250 Crawling: https://fastapi.tiangolo.com/features
# 40/250 Crawling: https://fastapi.tiangolo.com/advanced/openapi-callbacks
# 41/250 Crawling: https://fastapi.tiangolo.com/deployment/docker
# 42/250 Crawling: https://fastapi.tiangolo.com/tutorial/{{ no such element: dict object['author_link'] }}
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/%7B%7B%20no%20such%20element:%20dict%20object%5B'author_link'%5D%20%7D%7D
# 43/250 Crawling: https://fastapi.tiangolo.com/reference/websockets
# 44/250 Crawling: https://fastapi.tiangolo.com/yo
# 45/250 Crawling: https://fastapi.tiangolo.com/openapi
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/openapi
# 46/250 Crawling: https://fastapi.tiangolo.com/tutorial/tutorial/response-status-code
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/tutorial/response-status-code
# 47/250 Crawling: https://fastapi.tiangolo.com/tutorial/reference/apirouter
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/reference/apirouter
# 48/250 Crawling: https://fastapi.tiangolo.com/reference
# 49/250 Crawling: https://fastapi.tiangolo.com/tutorial/reference/dependencies
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/reference/dependencies
# 50/250 Crawling: https://fastapi.tiangolo.com/security/oauth2-scopes
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/security/oauth2-scopes
# 51/250 Crawling: https://fastapi.tiangolo.com/request
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/request
# 52/250 Crawling: https://fastapi.tiangolo.com/metadata
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/metadata
# 53/250 Crawling: https://fastapi.tiangolo.com/pl
# 54/250 Crawling: https://fastapi.tiangolo.com/tutorial/tutorial/schema-extra-example
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/tutorial/schema-extra-example
# 55/250 Crawling: https://fastapi.tiangolo.com/tutorial/help-fastapi
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/help-fastapi
# 56/250 Crawling: https://fastapi.tiangolo.com/history-design-future
# 57/250 Crawling: https://fastapi.tiangolo.com/management-tasks
# 58/250 Crawling: https://fastapi.tiangolo.com/additional-responses
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/additional-responses
# 59/250 Crawling: https://fastapi.tiangolo.com/tutorial/security/simple-oauth2
# 60/250 Crawling: https://fastapi.tiangolo.com/fastapi-cli
# 61/250 Crawling: https://fastapi.tiangolo.com/security/http-basic-auth
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/security/http-basic-auth
# 62/250 Crawling: https://fastapi.tiangolo.com/tutorial/reference/background
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/reference/background
# 63/250 Crawling: https://fastapi.tiangolo.com/tutorial/reference/security
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/reference/security
# 64/250 Crawling: https://fastapi.tiangolo.com/tutorial/handling-errors
# 65/250 Crawling: https://fastapi.tiangolo.com/tutorial/tutorial/debugging
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/tutorial/debugging
# 66/250 Crawling: https://fastapi.tiangolo.com/tutorial/tutorial/security/simple-oauth2
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/tutorial/security/simple-oauth2
# 67/250 Crawling: https://fastapi.tiangolo.com/tutorial/deployment/versions
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/deployment/versions
# 68/250 Crawling: https://fastapi.tiangolo.com/openapi-callbacks
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/openapi-callbacks
# 69/250 Crawling: https://fastapi.tiangolo.com/ja
# 70/250 Crawling: https://fastapi.tiangolo.com/em
# 71/250 Crawling: https://fastapi.tiangolo.com/tutorial/openapi/docs
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/openapi/docs
# 72/250 Crawling: https://fastapi.tiangolo.com/advanced/generate-clients
# 73/250 Crawling: https://fastapi.tiangolo.com/tutorial/tutorial/encoder
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/tutorial/encoder
# 74/250 Crawling: https://fastapi.tiangolo.com/openapi/models
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/openapi/models
# 75/250 Crawling: https://fastapi.tiangolo.com/https
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/https
# 76/250 Crawling: https://fastapi.tiangolo.com/tutorial/tutorial/first-steps
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/tutorial/first-steps
# 77/250 Crawling: https://fastapi.tiangolo.com/tutorial/advanced/path-operation-advanced-configuration
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/advanced/path-operation-advanced-configuration
# 78/250 Crawling: https://fastapi.tiangolo.com/httpconnection
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/httpconnection
# 79/250 Crawling: https://fastapi.tiangolo.com/security
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/security
# 80/250 Crawling: https://fastapi.tiangolo.com/tutorial/tutorial/query-params
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/tutorial/query-params
# 81/250 Crawling: https://fastapi.tiangolo.com/cloud
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/cloud
# 82/250 Crawling: https://fastapi.tiangolo.com/tutorial/security/first-steps
# 83/250 Crawling: https://fastapi.tiangolo.com/tutorial/how-to/graphql
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/how-to/graphql
# 84/250 Crawling: https://fastapi.tiangolo.com/reference/exceptions
# 85/250 Crawling: https://fastapi.tiangolo.com/response
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/response
# 86/250 Crawling: https://fastapi.tiangolo.com/project-generation
# 87/250 Crawling: https://fastapi.tiangolo.com/advanced-dependencies
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/advanced-dependencies
# 88/250 Crawling: https://fastapi.tiangolo.com/advanced/websockets
# 89/250 Crawling: https://fastapi.tiangolo.com/tutorial/extra-data-types
# 90/250 Crawling: https://fastapi.tiangolo.com/tutorial/dependencies
# 91/250 Crawling: https://fastapi.tiangolo.com/tutorial/features
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/features
# 92/250 Crawling: https://fastapi.tiangolo.com/reference/response
# 93/250 Crawling: https://fastapi.tiangolo.com/cookie-param-models
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/cookie-param-models
# 94/250 Crawling: https://fastapi.tiangolo.com/tutorial/how-to/configure-swagger-ui
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/how-to/configure-swagger-ui
# 95/250 Crawling: https://fastapi.tiangolo.com/reference/fastapi
# 96/250 Crawling: https://fastapi.tiangolo.com/tutorial/body
# 97/250 Crawling: https://fastapi.tiangolo.com/extra-data-types
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/extra-data-types
# 98/250 Crawling: https://fastapi.tiangolo.com/advanced/dataclasses
# 99/250 Crawling: https://fastapi.tiangolo.com/debugging
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/debugging
# 100/250 Crawling: https://fastapi.tiangolo.com/tutorial/advanced/behind-a-proxy
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/advanced/behind-a-proxy
# 101/250 Crawling: https://fastapi.tiangolo.com/response-directly
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/response-directly
# 102/250 Crawling: https://fastapi.tiangolo.com/python-types
# 103/250 Crawling: https://fastapi.tiangolo.com/staticfiles
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/staticfiles
# 104/250 Crawling: https://fastapi.tiangolo.com/tutorial/history-design-future
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/history-design-future
# 105/250 Crawling: https://fastapi.tiangolo.com/tutorial/tutorial/body-fields
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/tutorial/body-fields
# 106/250 Crawling: https://fastapi.tiangolo.com/testing
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/testing
# 107/250 Crawling: https://fastapi.tiangolo.com/tutorial/advanced/settings
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/advanced/settings
# 108/250 Crawling: https://fastapi.tiangolo.com/oauth2-jwt
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/oauth2-jwt
# 109/250 Crawling: https://fastapi.tiangolo.com/tutorial/uploadfile
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/uploadfile
# 110/250 Crawling: https://fastapi.tiangolo.com/security/simple-oauth2
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/security/simple-oauth2
# 111/250 Crawling: https://fastapi.tiangolo.com/tutorial/tutorial/middleware
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/tutorial/middleware
# 112/250 Crawling: https://fastapi.tiangolo.com/openapi-webhooks
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/openapi-webhooks
# 113/250 Crawling: https://fastapi.tiangolo.com/tutorial/advanced/openapi-callbacks
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/advanced/openapi-callbacks
# 114/250 Crawling: https://fastapi.tiangolo.com/exceptions
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/exceptions
# 115/250 Crawling: https://fastapi.tiangolo.com/advanced/custom-response
# 116/250 Crawling: https://fastapi.tiangolo.com/background-tasks
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/background-tasks
# 117/250 Crawling: https://fastapi.tiangolo.com/tutorial/advanced/security/oauth2-scopes
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/advanced/security/oauth2-scopes
# 118/250 Crawling: https://fastapi.tiangolo.com/contributing
# 119/250 Crawling: https://fastapi.tiangolo.com/tutorial/tutorial/dependencies/dependencies-in-path-operation-decorators
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/tutorial/dependencies/dependencies-in-path-operation-decorators
# 120/250 Crawling: https://fastapi.tiangolo.com/tutorial/websockets
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/websockets
# 121/250 Crawling: https://fastapi.tiangolo.com/request-forms-and-files
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/request-forms-and-files
# 122/250 Crawling: https://fastapi.tiangolo.com/tutorial/tutorial/security/first-steps
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/tutorial/security/first-steps
# 123/250 Crawling: https://fastapi.tiangolo.com/tutorial/tutorial/bigger-applications
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/tutorial/bigger-applications
# 124/250 Crawling: https://fastapi.tiangolo.com/security/oauth2-jwt
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/security/oauth2-jwt
# 125/250 Crawling: https://fastapi.tiangolo.com/tutorial/encoder
# 126/250 Crawling: https://fastapi.tiangolo.com/body-updates
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/body-updates
# 127/250 Crawling: https://fastapi.tiangolo.com/reference/encoders
# 128/250 Crawling: https://fastapi.tiangolo.com/path-params-numeric-validations
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/path-params-numeric-validations
# 129/250 Crawling: https://fastapi.tiangolo.com/tutorial/tutorial/body
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/tutorial/body
# 130/250 Crawling: https://fastapi.tiangolo.com/tutorial/advanced/response-directly
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/advanced/response-directly
# 131/250 Crawling: https://fastapi.tiangolo.com/get-current-user
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/get-current-user
# 132/250 Crawling: https://fastapi.tiangolo.com/deployment/cloud
# 133/250 Crawling: https://fastapi.tiangolo.com/tutorial/staticfiles
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/staticfiles
# 134/250 Crawling: https://fastapi.tiangolo.com/management
# 135/250 Crawling: https://fastapi.tiangolo.com/advanced/settings
# 136/250 Crawling: https://fastapi.tiangolo.com/docker
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/docker
# 137/250 Crawling: https://fastapi.tiangolo.com/how-to/custom-docs-ui-assets
# 138/250 Crawling: https://fastapi.tiangolo.com/vi
# 139/250 Crawling: https://fastapi.tiangolo.com/path-params
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/path-params
# 140/250 Crawling: https://fastapi.tiangolo.com/tutorial/sql-databases
# 141/250 Crawling: https://fastapi.tiangolo.com/tutorial/reference/openapi/docs
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/reference/openapi/docs
# 142/250 Crawling: https://fastapi.tiangolo.com/how-to/separate-openapi-schemas
# 143/250 Crawling: https://fastapi.tiangolo.com/tutorial/path-operation-configuration
# 144/250 Crawling: https://fastapi.tiangolo.com/static-files
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/static-files
# 145/250 Crawling: https://fastapi.tiangolo.com/tutorial/async
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/async
# 146/250 Crawling: https://fastapi.tiangolo.com/tutorial/how-to/custom-docs-ui-assets
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/how-to/custom-docs-ui-assets
# 147/250 Crawling: https://fastapi.tiangolo.com/body-nested-models
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/body-nested-models
# 148/250 Crawling: https://fastapi.tiangolo.com/tutorial/environment-variables
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/environment-variables
# 149/250 Crawling: https://fastapi.tiangolo.com/uploadfile
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/uploadfile
# 150/250 Crawling: https://fastapi.tiangolo.com/tutorial/dependencies/classes-as-dependencies
# 151/250 Crawling: https://fastapi.tiangolo.com/tutorial/tutorial/cookie-params
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/tutorial/cookie-params
# 152/250 Crawling: https://fastapi.tiangolo.com/reference/openapi/docs
# 153/250 Crawling: https://fastapi.tiangolo.com/tutorial/management-tasks
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/management-tasks
# 154/250 Crawling: https://fastapi.tiangolo.com/tutorial/deployment/server-workers
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/deployment/server-workers
# 155/250 Crawling: https://fastapi.tiangolo.com/tutorial/metadata
# 156/250 Crawling: https://fastapi.tiangolo.com/tutorial/first-steps
# 157/250 Crawling: https://fastapi.tiangolo.com/handling-errors
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/handling-errors
# 158/250 Crawling: https://fastapi.tiangolo.com/reference/uploadfile
# 159/250 Crawling: https://fastapi.tiangolo.com/release-notes
# 160/250 Crawling: https://fastapi.tiangolo.com/tutorial/background-tasks
# 161/250 Crawling: https://fastapi.tiangolo.com/response-model
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/response-model
# 162/250 Crawling: https://fastapi.tiangolo.com/tutorial/reference/request
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/reference/request
# 163/250 Crawling: https://fastapi.tiangolo.com/tutorial/debugging
# 164/250 Crawling: https://fastapi.tiangolo.com/zh/tutorial/first-steps
# 165/250 Crawling: https://fastapi.tiangolo.com/tutorial/how-to/extending-openapi
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/how-to/extending-openapi
# 166/250 Crawling: https://fastapi.tiangolo.com/tutorial/advanced
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/advanced
# 167/250 Crawling: https://fastapi.tiangolo.com/how-to/general
# 168/250 Crawling: https://fastapi.tiangolo.com/newsletter
# 169/250 Crawling: https://fastapi.tiangolo.com/tutorial/about
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/about
# 170/250 Crawling: https://fastapi.tiangolo.com/advanced/openapi-webhooks
# 171/250 Crawling: https://fastapi.tiangolo.com/tutorial/tutorial/request-forms
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/tutorial/request-forms
# 172/250 Crawling: https://fastapi.tiangolo.com/background
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/background
# 173/250 Crawling: https://fastapi.tiangolo.com/tutorial/learn
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/learn
# 174/250 Crawling: https://fastapi.tiangolo.com/dependencies-in-path-operation-decorators
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/dependencies-in-path-operation-decorators
# 175/250 Crawling: https://fastapi.tiangolo.com/tutorial/application-configuration
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/application-configuration
# 176/250 Crawling: https://fastapi.tiangolo.com/settings
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/settings
# 177/250 Crawling: https://fastapi.tiangolo.com/advanced/sql-databases-peewee
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/advanced/sql-databases-peewee
# 178/250 Crawling: https://fastapi.tiangolo.com/tutorial/resources
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/resources
# 179/250 Crawling: https://fastapi.tiangolo.com/pt/benchmarks
# 180/250 Crawling: https://fastapi.tiangolo.com/tutorial/reference/responses
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/reference/responses
# 181/250 Crawling: https://fastapi.tiangolo.com/security/first-steps
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/security/first-steps
# 182/250 Crawling: https://fastapi.tiangolo.com/dependencies/sub-dependencies
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/dependencies/sub-dependencies
# 183/250 Crawling: https://fastapi.tiangolo.com/tutorial/reference/templating
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/reference/templating
# 184/250 Crawling: https://fastapi.tiangolo.com/tutorial/fastapi-people
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/fastapi-people
# 185/250 Crawling: https://fastapi.tiangolo.com/apirouter
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/apirouter
# 186/250 Crawling: https://fastapi.tiangolo.com/deployment/https
# 187/250 Crawling: https://fastapi.tiangolo.com/tutorial/path-params
# 188/250 Crawling: https://fastapi.tiangolo.com/reference/background
# 189/250 Crawling: https://fastapi.tiangolo.com/tutorial/advanced/websockets
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/advanced/websockets
# 190/250 Crawling: https://fastapi.tiangolo.com/advanced/middleware
# 191/250 Crawling: https://fastapi.tiangolo.com/tutorial/static-files
# 192/250 Crawling: https://fastapi.tiangolo.com/tutorial/reference/staticfiles
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/reference/staticfiles
# 193/250 Crawling: https://fastapi.tiangolo.com/tutorial/tutorial/body-multiple-params
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/tutorial/body-multiple-params
# 194/250 Crawling: https://fastapi.tiangolo.com/wsgi
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/wsgi
# 195/250 Crawling: https://fastapi.tiangolo.com/status
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/status
# 196/250 Crawling: https://fastapi.tiangolo.com/tutorial/advanced/security
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/advanced/security
# 197/250 Crawling: https://fastapi.tiangolo.com/advanced/path-operation-advanced-configuration
# 198/250 Crawling: https://fastapi.tiangolo.com/tutorial/tutorial/dependencies/global-dependencies
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/tutorial/dependencies/global-dependencies
# 199/250 Crawling: https://fastapi.tiangolo.com/es/async
# 200/250 Crawling: https://fastapi.tiangolo.com/tutorial/external-links
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/external-links
# 201/250 Crawling: https://fastapi.tiangolo.com/dependencies/global-dependencies
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/dependencies/global-dependencies
# 202/250 Crawling: https://fastapi.tiangolo.com/custom-request-and-route
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/custom-request-and-route
# 203/250 Crawling: https://fastapi.tiangolo.com/advanced/testing-events
# 204/250 Crawling: https://fastapi.tiangolo.com/advanced/graphql
# 205/250 Crawling: https://fastapi.tiangolo.com/testing-websockets
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/testing-websockets
# 206/250 Crawling: https://fastapi.tiangolo.com/tutorial/tutorial/path-operation-configuration
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/tutorial/path-operation-configuration
# 207/250 Crawling: https://fastapi.tiangolo.com/tutorial/header-param-models
# 208/250 Crawling: https://fastapi.tiangolo.com/tutorial/tutorial/path-params-numeric-validations
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/tutorial/path-params-numeric-validations
# 209/250 Crawling: https://fastapi.tiangolo.com/tutorial/schema-extra-example
# 210/250 Crawling: https://fastapi.tiangolo.com/tutorial/security
# 211/250 Crawling: https://fastapi.tiangolo.com/tutorial/dependencies/global-dependencies
# 212/250 Crawling: https://fastapi.tiangolo.com/tutorial/advanced/additional-status-codes
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/advanced/additional-status-codes
# 213/250 Crawling: https://fastapi.tiangolo.com/cookie-params
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/cookie-params
# 214/250 Crawling: https://fastapi.tiangolo.com/tutorial/advanced/advanced-dependencies
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/advanced/advanced-dependencies
# 215/250 Crawling: https://fastapi.tiangolo.com/how-to/extending-openapi
# 216/250 Crawling: https://fastapi.tiangolo.com/advanced/behind-a-proxy
# 217/250 Crawling: https://fastapi.tiangolo.com/testing-events
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/testing-events
# 218/250 Crawling: https://fastapi.tiangolo.com/tutorial/benchmarks
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/benchmarks
# 219/250 Crawling: https://fastapi.tiangolo.com/deployment/concepts
# 220/250 Crawling: https://fastapi.tiangolo.com/ru
# 221/250 Crawling: https://fastapi.tiangolo.com/path-operation-advanced-configuration
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/path-operation-advanced-configuration
# 222/250 Crawling: https://fastapi.tiangolo.com/tutorial/fastapi-cli
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/fastapi-cli
# 223/250 Crawling: https://fastapi.tiangolo.com/dependencies/dependencies-with-yield
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/dependencies/dependencies-with-yield
# 224/250 Crawling: https://fastapi.tiangolo.com/zh/features
# 225/250 Crawling: https://fastapi.tiangolo.com/reference/security
# 226/250 Crawling: https://fastapi.tiangolo.com/fastapi
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/fastapi
# 227/250 Crawling: https://fastapi.tiangolo.com/advanced/sub-applications
# 228/250 Crawling: https://fastapi.tiangolo.com/tutorial/bigger-applications
# 229/250 Crawling: https://fastapi.tiangolo.com/pt/tutorial
# 230/250 Crawling: https://fastapi.tiangolo.com/testclient
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/testclient
# 231/250 Crawling: https://fastapi.tiangolo.com/tutorial/tutorial/body-updates
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/tutorial/body-updates
# 232/250 Crawling: https://fastapi.tiangolo.com/tutorial/advanced/response-cookies
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/advanced/response-cookies
# 233/250 Crawling: https://fastapi.tiangolo.com/zh/python-types
# 234/250 Crawling: https://fastapi.tiangolo.com/dependencies
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/dependencies
# 235/250 Crawling: https://fastapi.tiangolo.com/tutorial/tutorial/background-tasks
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/tutorial/background-tasks
# 236/250 Crawling: https://fastapi.tiangolo.com/tutorial/advanced/wsgi
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/advanced/wsgi
# 237/250 Crawling: https://fastapi.tiangolo.com/tutorial/deployment/cloud
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/deployment/cloud
# 238/250 Crawling: https://fastapi.tiangolo.com/tutorial/how-to/general
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/how-to/general
# 239/250 Crawling: https://fastapi.tiangolo.com/tutorial/newsletter
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/newsletter
# 240/250 Crawling: https://fastapi.tiangolo.com/how-to
# 241/250 Crawling: https://fastapi.tiangolo.com/encoders
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/encoders
# 242/250 Crawling: https://fastapi.tiangolo.com/reference/request
# 243/250 Crawling: https://fastapi.tiangolo.com/tutorial/oauth2-jwt
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/oauth2-jwt
# 244/250 Crawling: https://fastapi.tiangolo.com/he
# 245/250 Crawling: https://fastapi.tiangolo.com/tutorial/openapi
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/openapi
# 246/250 Crawling: https://fastapi.tiangolo.com/query-param-models
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/query-param-models
# 247/250 Crawling: https://fastapi.tiangolo.com/tutorial/dependencies/sub-dependencies
# 248/250 Crawling: https://fastapi.tiangolo.com/tutorial/advanced/testing-websockets
# An error occurred while fetching the URL: 404 Client Error: Not Found for url: https://fastapi.tiangolo.com/tutorial/advanced/testing-websockets
# 249/250 Crawling: https://fastapi.tiangolo.com/how-to/testing-database

# %% [markdown]
# #### 2. store the clean html in a folder

# %%
folder_name = docs_url.split("https://")[1].strip("/").strip()

# create a folder for the domain name
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# create an html file inside the folder for each page
for i, site in enumerate(doc_sites):
    with open(f"{folder_name}/{i}.md", "w") as f:
        f.write(site)

# for eas of testing store the docs url dict in a pickle file
with open("docs_url.pickle", "wb") as f:
    pickle.dump(doc_sites, f)
